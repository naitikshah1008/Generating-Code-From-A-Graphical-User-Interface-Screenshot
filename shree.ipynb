# %%
# !pip install torch torchvision torchaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /nfs/stak/a1/rhel5apps/conda/24.3/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /nfs/stak/a1/rhel5apps/conda/24.3/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.1.105)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /nfs/stak/users/badhes/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /nfs/stak/a1/rhel5apps/conda/24.3/lib/python3.10/site-packages (from torchvision) (2.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /nfs/stak/a1/rhel5apps/conda/24.3/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /nfs/stak/a1/rhel5apps/conda/24.3/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)

# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# /nfs/hpc/share/badhes/blstm-pix2code/myenv/bin/python
# ['/usr/lib64/python39.zip', '/usr/lib64/python3.9', '/usr/lib64/python3.9/lib-dynload', '', '/nfs/hpc/share/badhes/blstm-pix2code/myenv/lib64/python3.9/site-packages', '/nfs/hpc/share/badhes/blstm-pix2code/myenv/lib/python3.9/site-packages']

# %%
from util import UIDataset, Vocabulary
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch
from torch.utils.data import DataLoader
from model import *
from torchvision import transforms
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from util import UIDataset, Vocabulary
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#
# File /nfs/hpc/share/badhes/blstm-pix2code/pix2code/pytorch_pix2code/util.py:1
# ----> 1 from torch.utils import data
#       2 import torchvision.transforms as transforms
#       3 import os
#
# ModuleNotFoundError: No module named 'torch'
